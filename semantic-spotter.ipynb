# %%
# configurations

config = {
    'data_path' : '/Users/RajivGaba/aiml_projects/Semantic Spotter/Data/',
    'chunk_size' : 1000,
    'chunk_overlap' : 200,
    'vector_store_name' : "faiss_index",
    'hf_token' : "*****",
    'embedding_model' : 'all-MiniLM-L6-v2',
    'refresh_vector_store' : 'N',
    'cross_encoder_model': 'cross-encoder/ms-marco-MiniLM-L-6-v2',
    'PPLX_API_KEY' : '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'
}

# %%
# install required packages

! pip install -qU langchain-community pymupdf
! pip install -qU langchain_huggingface
! pip install sentence-transformers

# %%
# import libraries

import os, glob
import importlib

# Restart kernel if needed
try:
    importlib.reload(importlib)
except:
    pass

from langchain_community.document_loaders import PyMuPDFLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain_huggingface import HuggingFaceEmbeddings
from langchain.vectorstores import FAISS
from sentence_transformers import CrossEncoder, util

# %%
# Define reusable functions

def get_data_chunks(pdf_file):
    loader = PyMuPDFLoader(pdf_file)
    documents = loader.load()

    # chunking/splitting
    text_splitter = RecursiveCharacterTextSplitter(
        chunk_size=config['chunk_size'],
        chunk_overlap=config['chunk_overlap']
    )
    text_chunks = text_splitter.split_documents(documents=documents)
    return text_chunks

def get_all_pdf_files(data_path):
    pdf_files = glob.glob(os.path.join(data_path, "*.pdf"))
    return pdf_files

def get_embeddings_model():
    embedding_model = HuggingFaceEmbeddings(model_name=config['embedding_model'], show_progress=True)
    return embedding_model

def create_vector_store(text_chunks, embedding_model):
    if config['refresh_vector_store'] == 'Y' and os.path.exists(config['vector_store_name']):
        vector_store = FAISS.from_documents(text_chunks, embedding_model)
        vector_store.save_local(config['vector_store_name'])
    else:
        vector_store = FAISS.load_local(config['vector_store_name'], embedding_model, allow_dangerous_deserialization=True)

def get_cross_encoder_score(query, results):
    cross_encoder = CrossEncoder(config['cross_encoder_model'])
    for i, res in enumerate(results):
        ce_score = cross_encoder.predict([query, res.page_content])
        print(ce_score)

# %%
if __name__ == "__main__":
    chunked_data = []
    pdf_files = get_all_pdf_files(config['data_path'])
    for pdf_file in pdf_files:
        # print(pdf_file)
        text_chunks = get_data_chunks(pdf_file)
        chunked_data.extend(text_chunks)

    embedding_model = get_embeddings_model()
    create_vector_store(chunked_data, embedding_model)
    vector_store = FAISS.load_local(config['vector_store_name'], embedding_model, allow_dangerous_deserialization=True)
    # get_cross_encoder_score(query, results)
# Out:
# Batches: 100%|██████████| 5/5 [00:00<00:00, 11.29it/s]

# %%
query = "what is the global Webserver plug-in Configuration required for installation"
results = vector_store.similarity_search(query, k=10)
for i, res in enumerate(results):
    print(i, res.page_content,  "\n"*3)
# Out:
# Batches: 100%|██████████| 1/1 [00:00<00:00,  1.16it/s]
# 0 Manual Post Installation from Solutions .................................................................... 21
# 6.2.
# Update global Webserver plug-in Configuration (Only for WAS cluster webserver
# setup) ........................................................................................................................ 21
# 6.3.
# Restart OHS Server (Only for WEBLOGIC Cluster webserver setup) ...................... 21
# 6.4.
# Change Binding for jBoss .......................................................................................... 22
# 6.5.
# Moving all DB Objects to Default TableSpace in Postgres ....................................... 22
# 6.6.
# Restart JBPM ............................................................................................................ 22
# 6.7.
# CSIS DB Configuration .............................................................................................. 23
# 6.8.
#
#
#
# 1 Ip address : 10.11.32.29 User Name:Rajiv Gaba       Time Stamp : 3/7/2025 5:56:12 PM
# Finacle Copyright
# Finacle Universal Banking Solution 10.2.25 Installation Guide
#
# © EdgeVerve Systems Limited
# External Confidential
# Page 18 of 54
# Note: The environment validation does not support multiple webservers, so errors/failures
# shown in case multiple webservers is to be configured should be ignored.
#
#
#
# 2 fininfra/SSO. Select different solution from dropdown of fininfra/SSO desktop and validate if the
# login to all the solution is successful.
# 6.2. Update global Webserver plug-in Configuration (Only for WAS cluster
# webserver setup)
# 1. Log in to DMGR admin console with URL https://<DMGR_HOST_NAME>:< DMGR
# Administrative console port>/ibm/console
# 2. Click “Environment” on the left side panel to expand
# 3. Click “Update global Webserver plug-in configuration”
# 4. Click “OK” on the screen
# 5. Go to “Servers” on the left side panel to expand
# 6. Click on “All servers” and select the checkbox for webserver and select Action as
# “Generate Plugin” from the dropdown and press “Submit Action”.
# 7. Select the checkbox for webserver and select Action as “Propagate Plugin” from the
# dropdown and press “Submit Action”.
# 6.3. Restart OHS Server (Only for WEBLOGIC Cluster webserver setup)
# •
# Start the node manager using following command if not running already
#
#
#
# 3 Ip address : 10.11.32.29 User Name:Rajiv Gaba       Time Stamp : 3/7/2025 5:56:12 PM
# Finacle Copyright
# Finacle Universal Banking Solution 10.2.25 Installation Guide
#
# © EdgeVerve Systems Limited
# External Confidential
# Page 12 of 54
# 17.
# GSK_HOME_PATH
# Provide the path of gskcmd including filename:
# e.g.
# /WAS/WASIHS9009/IBM/HTTPServer/bin/gs
# kcmd
# 18.
# PLUGIN_INSTALL_LOCATION
# Webserver plugins install location:
# e.g.
# /WAS/WASIHS9009/IBM/WebSphere/Plugins
# 19.
# MANAGED_APP_SERVER
# Select N , if deployment will be done by FDM+.
#
# Inputs Specific to JBOSS:
# 19.
# JBOSS_PORT_OFFSET
# Port value provided should be free and smaller
# number like 200,400 .
# Inputs Specific to WebLogic:
# 20.
# ADMINSRVR_USER_NAME
# Provide OS user of WebLogic admin server.
#
# 21.
# ADMINSRVR_MACHINE_NAME
# Provide hostname where WebLogic admin server
# is installed.
# 22.
# OHS_INSTANCE_PATH
# Path where OHS instance is created. Path should
# end with webserver domain/instance name and
#
#
#
# 4 Webserver Environment Validation
# Webserver validation activity needs to be executed in the machine with the OS user by which
# webserver configuration is planned.
# Webserver validation can be fired using the command given below
# cd <COMMON_ROOT_PATH>/CUT/FDM+
# <COMMON_ROOT_PATH>/CUT/FDM+/script/validateWebServer.sh
# <COMMON_ROOT_PATH>/CUT/FDM+/properties/fdm_inputs.properties
# Check the Logs present in
# <WEBSERVER_USER_HOME>/<Finacle_Install_ID>/FDMStore/FDMLogs/
# Env_Validation_Status.log to see the status of BE layer environment validation.
# Install_User_Log.txt present in the same path as above will have the consolidated list of
# Successful and failed parameters and configurations.
#
#
#
# 5 9.3.
# FE Application Server Upgrade ................................................................................. 43
# 9.4.
# License Update ......................................................................................................... 45
# 9.5.
# SSO UPDATE ........................................................................................................... 47
# 9.6.
# FDM Sync Utility ........................................................................................................ 48
# 9.7.
# Echo Services – Application sanity testing (only applicable for 11.5 and above) ...... 49
# 9.8.
# DataSource DB Password Modification for JBOSS EAP .......................................... 49
# 9.9.
# Installation Cleanup ................................................................................................... 50
# 9.10. Central Restart .......................................................................................................... 51
#
#
#
# 6 9.3. FE Application Server Upgrade
# Due to end of life support or technology upgrade existing installation FE components may need
# to be re installed/upgraded. The following steps can be followed to achieve the requirement.
# Front end version upgrade utility is applicable only for application server front end component.
# WebServer(s) changes, if applicable must be handled manually as version upgrade facility for
# webserver is not scoped for this utility.
#
#
#
# 7 Provide hostname where WebLogic admin server
# is installed.
# 22.
# OHS_INSTANCE_PATH
# Path where OHS instance is created. Path should
# end with webserver domain/instance name and
# contain bin, config and nodemanager directories.
# e.g.
# /WAS/oracle_http/Oracle/Middleware/Or
# acle_Home/user_projects/domains/base_
# domain
# 23.
# WEBLOGIC_TARGET_NAME
# In case of cluster, this should be name of cluster
# and managed server name in case of single
# environment.
# e.g. OHSCluster
# 24.
# WEBLOGIC_CRM_TARGET_NA
# ME
# If the environment is of cluster type, provide
# managed server names separated by comma
# according to number of nodes or If the
# environment is of single server type, provide
# managed server name.
# e.g. OHS225SERVER0,OHS225SERVER1
#
#
#
# 8 Ip address : 10.11.32.29 User Name:Rajiv Gaba       Time Stamp : 3/7/2025 5:56:12 PM
# Finacle Copyright
# Finacle Universal Banking Solution 10.2.25 Installation Guide
#
# © EdgeVerve Systems Limited
# External Confidential
# Page 52 of 54
# 10.  Application Server Console Details
# 10.1.
#  Weblogic admin console
# The below is the admin console URL for Weblogic application server.
# http://< ADMINSRVR_MACHINE_NAME>:<admin port>/console
# For single node ADMINSRVR_MACHINE_NAME is the frontend hostname
# For cluster ADMINSRVR_MACHINE_NAME is asked during inputs collection.” Admin Server
# Machine Name”
# The admin server port can be taken from listen-port section of config.xml in path
# <frontend installation
# directory>/../<Installid>domain/config/config.xml of admin server.
# <server>
#     <name>AdminServer</name>
#     <listen-port>14051</listen-port>
#     <listen-address/>
#     <server-start>
#       <name>AdminServer</name>
#       <arguments>-verbose:class -
#
#
#
# 9 Ip address : 10.11.32.29 User Name:Rajiv Gaba       Time Stamp : 3/7/2025 5:56:12 PM
# Finacle Copyright
# Finacle Universal Banking Solution 10.2.25 Installation Guide
#
# © EdgeVerve Systems Limited
# External Confidential
# Page 8 of 54
# 2.4. AppServer Profile/Cluster Creation (Only for Webspher Application
# Server)
# WAS profile/cluster is automatically created during Frontend Installation if “Do the APPServer
# profiles exist” value is set as “No” during Input Collection.
# If Profile/Cluster is created outside FDM+ then follow the prerequisite XL to do the required
# configuration for Finacle.
# ** If the OS is Sun Solaris then the profile/cluster has to be created outside FDM+ and “Do the
# APPServer profiles exist” value to be given as “Yes”
# For the profile created by FDM+ after Frontend Installation, WAS Admin Console can be
# accessed with below URL and credentials.
# URL - https://<WAS PROFILE HOST NAME>:< PROFILE Administrative Secure
# console port>/ibm/console

# %%
! pip install -qU "langchain-perplexity"
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)

# %%
from langchain.chat_models import init_chat_model
os.environ["PPLX_API_KEY"] = config['PPLX_API_KEY']
model = init_chat_model("llama-3.1-sonar-small-128k-online", model_provider="perplexity")
model.invoke("hello dear")

# %%
def get_llm_response():
    pass
